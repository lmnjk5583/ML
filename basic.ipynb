# %%
# 분류 예습

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.svm import SVC

# %%
from sklearn.svm import SVR

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
pd.read_csv('C:/ex/data/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df=pd.read_csv('C:/ex/data/titanic.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
titanic_df=sns.load_dataset('titanic')

# %%
titanic_df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic_df['deck']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
titanic_df['deck'].value_counts()
# Out:
# deck
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
titanic_df['deck'].value_counts(dropna=False)   #결측치도 같이 새는 dropna=False
# Out:
# deck
# NaN    688
# C       59
# B       47
# D       33
# E       32
# A       15
# F       13
# G        4
# Name: count, dtype: int64

# %%
tit_df=titanic_df['deck'].value_counts(dropna=False)

# %%
tit_df
# Out:
# deck
# NaN    688
# C       59
# B       47
# D       33
# E       32
# A       15
# F       13
# G        4
# Name: count, dtype: int64

# %%
tit_df.sum()
# Out:
# np.int64(891)

# %%
tit_df
# Out:
# deck
# NaN    688
# C       59
# B       47
# D       33
# E       32
# A       15
# F       13
# G        4
# Name: count, dtype: int64

# %%
# 결측값 관련 인식(0, False, '', None, null, NA, Nan)

# %%
tit_df
# Out:
# deck
# NaN    688
# C       59
# B       47
# D       33
# E       32
# A       15
# F       13
# G        4
# Name: count, dtype: int64

# %%
titanic_df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic_df.isnull().sum(axis=1)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    2
# 889    0
# 890    1
# Length: 891, dtype: int64

# %%
titanic_df.dropna(axis=1)   #결측치 날리기
# Out:
#      survived  pclass     sex  sibsp  ...    who  adult_male alive  alone
# 0           0       3    male      1  ...    man        True    no  False
# 1           1       1  female      1  ...  woman       False   yes  False
# 2           1       3  female      0  ...  woman       False   yes   True
# 3           1       1  female      1  ...  woman       False   yes  False
# 4           0       3    male      0  ...    man        True    no   True
# ..        ...     ...     ...    ...  ...    ...         ...   ...    ...
# 886         0       2    male      0  ...    man        True    no   True
# 887         1       1  female      0  ...  woman       False   yes   True
# 888         0       3  female      1  ...  woman       False    no  False
# 889         1       1    male      0  ...    man        True   yes   True
# 890         0       3    male      0  ...    man        True    no   True
#
# [891 rows x 11 columns]

# %%
titanic_df.dropna(axis=1, thresh=500, inplace=True)

# %%
titanic_df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
# 결측치 삭제 후에는 항상 정확하게 행(row)과 열(columns)의 갯수가 맞는지 반드시 확인

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
891 - 714
# Out:
# 177

# %%
titanic_df['age'].isna().sum()
# Out:
# np.int64(177)

# %%
titanic_df.dropna(subset=['age'], axis=0, inplace=True)

# %%
titanic_df['age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
mean_age=titanic_df['age'].mean()

# %%
titanic_df['age'].fillna(mean_age, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5224\3419352568.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df['age'].fillna(mean_age, inplace=True)

# %%
titanic_df['embark_town']
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
titanic_df['embark_town'].isna().sum()
# Out:
# np.int64(2)

# %%
titanic_df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
titanic_df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
titanic_df.mode()
# Out:
#    survived  pclass   sex   age  ...  adult_male  embark_town  alive alone
# 0         0       3  male  24.0  ...        True  Southampton     no  True
#
# [1 rows x 14 columns]

# %%
titanic_df['embark_town'].mode()[0]
# Out:
# 'Southampton'

# %%
titanic_df['embark_town'].value_counts().idxmax()   # 가장 최댓갑인 것을 출력
# Out:
# 'Southampton'

# %%
most_freq=titanic_df['embark_town'].mode()[0]

# %%
titanic_df['embark_town'].fillna('Southampton', inplace=True)

# %%
titanic_df['embark_town']
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
np.sqrt(5**2+12**2)
# Out:
# np.float64(13.0)

# %%
np.sqrt(9**2+12**2)
# Out:
# np.float64(15.0)

# %%
from collections import deque

# %%
deque_list = deque()

# %%
for i in range(5):
    deque_list.append(i)

# %%
print(deque_list)
# Out:
# deque([0, 1, 2, 3, 4])

# %%
deque_list.pop()
# Out:
# 4

# %%
deque_list.pop()
# Out:
# 3

# %%
deque_list.pop()
# Out:
# 2

# %%
deque_list
# Out:
# deque([0, 1])

# %%
deque_list = deque()
for i in range(5):
    deque_list.appendleft(i)

# %%
print(deque_list)
# Out:
# deque([4, 3, 2, 1, 0])

# %%
deque_list = deque()

# %%
for i in range(5):
    deque_list.appendleft(i)

# %%
deque_list
# Out:
# deque([4, 3, 2, 1, 0])

# %%
print(deque(reversed(deque_list)))
# Out:
# deque([0, 1, 2, 3, 4])

# %%
from collections import deque
deque_list = deque(['a', 'b', 'c'])

# %%
deque_list
# Out:
# deque(['a', 'b', 'c'])

# %%
deque_list.rotate(1)
print(deque_list)
# Out:
# deque(['c', 'a', 'b'])

# %%
deque_list.rotate(-2)
print(deque_list)
# Out:
# deque(['c', 'a', 'b'])

# %%
deque_list.appendleft('c')
print(deque_list)
# Out:
# deque(['c', 'b', 'c', 'a'])

# %%
deque_list = deque(['c', 'a', 'b'])
print(deque_list)
# Out:
# deque(['c', 'a', 'b'])

# %%
deque_list = deque(['a', 'b', 'c'])
print(deque_list)
# Out:
# deque(['a', 'b', 'c'])

# %%
dictionary = {"a": 1, "b": 2, "c": 3}

# %%
dictionary.setdefault( 'b', 4 ) 
dictionary.setdefault( 'd', 5 )
# Out:
# 5

# %%
dictionary["c"]  = dictionary["d"]

# %%
dictionary["c"]
# Out:
# 5

# %%
dictionary["d"]
# Out:
# 5

# %%
fruits = ('apple','banana','cherry','strawberry')

# %%
3**5
# Out:
# 243

# %%
# 불가능(immuratable)

# %%
country_code={"America":1,"Korea":82,"China":86,"Japan":81}

# %%
country_code.values()
# Out:
# dict_values([1, 82, 86, 81])

# %%
a=0
midterm_set = set([1, 5, 7, 4, 3, 2, 1, 1, 2, 3])

# %%
for i in midterm_set:
    a = a+i
print(a)
# Out:
# 22

# %%
def delete_a_list_element(list_data, element_value):
    if element_value in list_data:
        list_data.remove(element_value)
        return list_data
    else:
        return "False"

# %%
list_data = ['a', 1, 'gachon', '2016.0']

# %%
list_data
# Out:
# ['a', 1, 'gachon', '2016.0']

# %%
element = float(2016)

# %%
result = delete_a_list_element(list_data, element)

# %%
element
# Out:
# 2016.0

# %%
print(result)
# Out:
# False

# %%
def add_number(original_list):
    original_list += [1]

# %%
mylist = [1, 2, 3, 4]

# %%
add_number(mylist)

# %%
mylist
# Out:
# [1, 2, 3, 4, 1]

# %%
print(set(mylist))   # set은 중괄호
# Out:
# {1, 2, 3, 4}

# %%
a = [3, "apple", 2016, 4]
b = a.pop(0)     # [3]
c = a.pop(1)     # [2016]       ['apple',2016,4]
print(b + c)
# Out:
# 2019

# %%
def week_seven(sentence1):
    cells = set(sentence1.replace(' ','').lower())    #
    return cells

# %%
sentence_a = "The quick brown fox jumps over the lazy dog"
sentence_b = "I love you"    
print(len(week_seven(sentence_a)-week_seven(sentence_b)))
# Out:
# 19

# %%
def test(num): 
    if num == 1:
        return True
    elif num == 2:
        return False
    else:
        print('1과 2만 넣으세요')

# %%
result1=test(1)
result2=test(2)
result3=test(3)
print(result1,result2,result3)
# Out:
# 1과 2만 넣으세요
# True False None

# %%
tuple_1 = (1, 2, 3)
tuple_2 = (4, 5, 6)

# %%
tuple_1 + tuple_2
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
dict_1 = {2:1, 4:2, 6:3, 8:4, 10:6}

# %%
dict_keys = list(dict_1.keys())
dict_values = list(dict_1.values())

# %%
dict_keys
# Out:
# [2, 4, 6, 8, 10]

# %%
dict_values
# Out:
# [1, 2, 3, 4, 6]

# %%
dict_2 = dict()

# %%
for i in range(len(dict_keys)):
    dict_2[dict_values[i]] = dict_keys[i]
